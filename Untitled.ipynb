# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator
# %matplotlib inline

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))
sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Première phase: exploration/nettoyage des données ###################
ax1 = sns.violinplot('arrondissement', 'price', data=data, hue= 'arrondissement')
ax1.minorticks_on()
ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
ax1.grid(which='minor', axis='x', linewidth=1)

sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
ax1.minorticks_on()
#ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
ax1.grid(which='minor', axis='x', linewidth=1)

sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
ax1.minorticks_on()
#ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
ax1.grid(which='minor', axis='x', linewidth=1)

sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
ax1.minorticks_on()
#ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
#ax1.grid(which='minor', axis='x', linewidth=1)

sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
#ax1.minorticks_on()
#ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
#ax1.grid(which='minor', axis='x', linewidth=1)

sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
#affichage du graphique
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
#affiche sur le graphique des petite graduation
#ax1.minorticks_on()
ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
ax1.grid(which='minor', axis='x', linewidth=1)

sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
#affichage du graphique
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
#affiche sur le graphique des petite graduation sur l'axe x et y mais aussi à l'interieur du graphique  (des grandes lignes verticale)
#ax1.minorticks_on()
#ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
ax1.grid(which='minor', axis='x', linewidth=1)

sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
#affichage du graphique
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
#affiche sur le graphique des petite graduation sur l'axe x et y mais aussi à l'interieur du graphique  (des grandes lignes verticale)
#ax1.minorticks_on()
affiche les lignes verticale qui sépare nos schémas
#ax1.xaxis.set_minor_locator(AutoMinorLocator(2))

#ax1.grid(which='minor', axis='x', linewidth=1)

sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#   File "<ipython-input-11-a866be7a4f9e>", line 39
#     affiche les lignes verticale qui sépare nos schémas
#               ^
# SyntaxError: invalid syntax

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
#affichage du graphique
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
#affiche sur le graphique des petite graduation sur l'axe x et y mais aussi à l'interieur du graphique  (des grandes lignes verticale)
#ax1.minorticks_on()
#affiche les lignes verticale qui sépare nos schémas
#ax1.xaxis.set_minor_locator(AutoMinorLocator(2))

#ax1.grid(which='minor', axis='x', linewidth=1)

sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator
from mpl_toolkits.mplot3d import Axes3D

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
#affichage du graphique
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
#affiche sur le graphique des petite graduation sur l'axe x et y mais aussi à l'interieur du graphique  (des grandes lignes verticale)
ax1.minorticks_on()
#affiche les lignes verticale qui sépare nos schémas
ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
#ordonne l'axe mineur si il existe pour le schéma
ax1.grid(which='minor', axis='x', linewidth=1)


################### On croise le prix avec la surface pour avoir une vision plus claire ###################
#affcihage du graphe 3D
fig = plt.figure().gca(projection='3d')

# Pour faciliter la visualisation, on va changer la valeur de l'arrondissement (10) en 5
tmp_arr = data['arrondissement'][:]
print(tmp_arr)
sys.exit(0)
tmp_arr[tmp_arr == 10] = 5

fig.scatter(tmp_arr, data['surface'], data['price'], c=tmp_arr, cmap="viridis")
plt.show()


sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 807    10.0
# 808    10.0
# 809    10.0
# 810    10.0
# 811    10.0
# Name: arrondissement, Length: 812, dtype: float64
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator
from mpl_toolkits.mplot3d import Axes3D

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
#affichage du graphique
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
#affiche sur le graphique des petite graduation sur l'axe x et y mais aussi à l'interieur du graphique  (des grandes lignes verticale)
ax1.minorticks_on()
#affiche les lignes verticale qui sépare nos schémas
ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
#ordonne l'axe mineur si il existe pour le schéma
ax1.grid(which='minor', axis='x', linewidth=1)


################### On croise le prix avec la surface pour avoir une vision plus claire ###################
#affcihage du graphe 3D
fig = plt.figure().gca(projection='3d')

# Pour faciliter la visualisation, on va changer la valeur de l'arrondissement (10) en 5
tmp_arr = data['arrondissement'][:]
#print(tmp_arr)
sys.exit(0)
tmp_arr[tmp_arr == 10] = 5

fig.scatter(tmp_arr, data['surface'], data['price'], c=tmp_arr, cmap="viridis")
plt.show()


sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator
from mpl_toolkits.mplot3d import Axes3D

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
#affichage du graphique
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
#affiche sur le graphique des petite graduation sur l'axe x et y mais aussi à l'interieur du graphique  (des grandes lignes verticale)
ax1.minorticks_on()
#affiche les lignes verticale qui sépare nos schémas
ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
#ordonne l'axe mineur si il existe pour le schéma
ax1.grid(which='minor', axis='x', linewidth=1)


################### On croise le prix avec la surface pour avoir une vision plus claire ###################
#affcihage du graphe 3D
fig = plt.figure().gca(projection='3d')

# Pour faciliter la visualisation, on va changer la valeur de l'arrondissement (10) en 5
#on récupère la valeur de tous les indices
tmp_arr = data['arrondissement'][:]
#et on change celle-ci
tmp_arr[tmp_arr == 10] = 5

fig.scatter(tmp_arr, data['surface'], data['price'], c=tmp_arr, cmap="viridis")
plt.show()


sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator
from mpl_toolkits.mplot3d import Axes3D

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
#affichage du graphique
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
#affiche sur le graphique des petite graduation sur l'axe x et y mais aussi à l'interieur du graphique  (des grandes lignes verticale)
ax1.minorticks_on()
#affiche les lignes verticale qui sépare nos schémas
ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
#ordonne l'axe mineur si il existe pour le schéma
ax1.grid(which='minor', axis='x', linewidth=1)


################### On croise le prix avec la surface pour avoir une vision plus claire ###################
#affcihage du graphe 3D
fig = plt.figure().gca(projection='3d')

# Pour faciliter la visualisation, on va changer la valeur de l'arrondissement (10) en 5
#on récupère la valeur de tous les indices
tmp_arr = data['arrondissement'][:]
#et on change celle-ci
tmp_arr[tmp_arr == 10] = 5

#set tous les points du schéma 3D fig.scatte(axe x, axe z, axe y)
fig.scatter(tmp_arr, data['surface'], data['price'], c=data['price'], cmap="viridis")
plt.show()


sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator
from mpl_toolkits.mplot3d import Axes3D

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
#affichage du graphique
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
#affiche sur le graphique des petite graduation sur l'axe x et y mais aussi à l'interieur du graphique  (des grandes lignes verticale)
ax1.minorticks_on()
#affiche les lignes verticale qui sépare nos schémas
ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
#ordonne l'axe mineur si il existe pour le schéma
ax1.grid(which='minor', axis='x', linewidth=1)


################### On croise le prix avec la surface pour avoir une vision plus claire ###################
#affcihage du graphe 3D
fig = plt.figure().gca(projection='3d')

# Pour faciliter la visualisation, on va changer la valeur de l'arrondissement (10) en 5
#on récupère la valeur de tous les indices
tmp_arr = data['arrondissement'][:]
#et on change celle-ci
tmp_arr[tmp_arr == 10] = 5

#set tous les points du schéma 3D fig.scatte(axe x, axe z, axe y), c défini en fonction de quoi les couleurs change pour différencier les points
fig.scatter(tmp_arr, data['surface'], data['price'], c=tmp_arr, cmap="viridis")
#on affiche le graphe 3D
plt.show()


################### régression spécifique pour séparer jeu de données d'entrainement/jeu de données de test ###################

xtrain, xtest, ytrain, ytest = train_test_split(data[["surface", "arrondissement"]], data[["price"]], test_size=0.3)

print(xtrain)

sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
#      surface  arrondissement
# 457     80.0             3.0
# 426     33.0             3.0
# 183     75.0             2.0
# 515    150.0             4.0
# 723     20.6             5.0
# ..       ...             ...
# 203     45.0             2.0
# 601     72.0             4.0
# 504     26.0             4.0
# 210     50.0             2.0
# 278     18.0             2.0
#
# [568 rows x 2 columns]
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator
from mpl_toolkits.mplot3d import Axes3D

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
#affichage du graphique
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
#affiche sur le graphique des petite graduation sur l'axe x et y mais aussi à l'interieur du graphique  (des grandes lignes verticale)
ax1.minorticks_on()
#affiche les lignes verticale qui sépare nos schémas
ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
#ordonne l'axe mineur si il existe pour le schéma
ax1.grid(which='minor', axis='x', linewidth=1)


################### On croise le prix avec la surface pour avoir une vision plus claire ###################
#affcihage du graphe 3D
fig = plt.figure().gca(projection='3d')

# Pour faciliter la visualisation, on va changer la valeur de l'arrondissement (10) en 5
#on récupère la valeur de tous les indices
tmp_arr = data['arrondissement'][:]
#et on change celle-ci
tmp_arr[tmp_arr == 10] = 5

#set tous les points du schéma 3D fig.scatte(axe x, axe z, axe y), c défini en fonction de quoi les couleurs change pour différencier les points
fig.scatter(tmp_arr, data['surface'], data['price'], c=tmp_arr, cmap="viridis")
#on affiche le graphe 3D
plt.show()


################### régression spécifique pour séparer jeu de données d'entrainement/jeu de données de test ###################

xtrain, xtest, ytrain, ytest = train_test_split(data[["surface", "arrondissement"]], data[["price"]], test_size=0.3)

print(ytrain)

sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
#      price
# 718    795
# 660   3770
# 45    4722
# 809   1280
# 347   1740
# ..     ...
# 102   2587
# 338   2090
# 808    700
# 244   1835
# 731   1050
#
# [568 rows x 1 columns]
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator
from mpl_toolkits.mplot3d import Axes3D

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
#affichage du graphique
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
#affiche sur le graphique des petite graduation sur l'axe x et y mais aussi à l'interieur du graphique  (des grandes lignes verticale)
ax1.minorticks_on()
#affiche les lignes verticale qui sépare nos schémas
ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
#ordonne l'axe mineur si il existe pour le schéma
ax1.grid(which='minor', axis='x', linewidth=1)


################### On croise le prix avec la surface pour avoir une vision plus claire ###################
#affcihage du graphe 3D
fig = plt.figure().gca(projection='3d')

# Pour faciliter la visualisation, on va changer la valeur de l'arrondissement (10) en 5
#on récupère la valeur de tous les indices
tmp_arr = data['arrondissement'][:]
#et on change celle-ci
tmp_arr[tmp_arr == 10] = 5

#set tous les points du schéma 3D fig.scatte(axe x, axe z, axe y), c défini en fonction de quoi les couleurs change pour différencier les points
fig.scatter(tmp_arr, data['surface'], data['price'], c=tmp_arr, cmap="viridis")
#on affiche le graphe 3D
plt.show()


################### régression spécifique pour séparer jeu de données d'entrainement/jeu de données de test ###################

#dans les x on met surface et arrondissement et dans les y on met le price et on prend 30% des données pour le train
xtrain, xtest, ytrain, ytest = train_test_split(data[["surface", "arrondissement"]], data[["price"]], test_size=0.8)

print(xtrain)

sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
#      surface  arrondissement
# 38     97.00             1.0
# 319   106.00             3.0
# 173    19.00             2.0
# 687    42.44             5.0
# 635    23.00             4.0
# ..       ...             ...
# 702    25.00             5.0
# 559    40.00             4.0
# 166    75.00             2.0
# 589    18.39             4.0
# 710    48.00             5.0
#
# [162 rows x 2 columns]
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator
from mpl_toolkits.mplot3d import Axes3D

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
#affichage du graphique
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
#affiche sur le graphique des petite graduation sur l'axe x et y mais aussi à l'interieur du graphique  (des grandes lignes verticale)
ax1.minorticks_on()
#affiche les lignes verticale qui sépare nos schémas
ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
#ordonne l'axe mineur si il existe pour le schéma
ax1.grid(which='minor', axis='x', linewidth=1)


################### On croise le prix avec la surface pour avoir une vision plus claire ###################
#affcihage du graphe 3D
fig = plt.figure().gca(projection='3d')

# Pour faciliter la visualisation, on va changer la valeur de l'arrondissement (10) en 5
#on récupère la valeur de tous les indices
tmp_arr = data['arrondissement'][:]
#et on change celle-ci
tmp_arr[tmp_arr == 10] = 5

#set tous les points du schéma 3D fig.scatte(axe x, axe z, axe y), c défini en fonction de quoi les couleurs change pour différencier les points
fig.scatter(tmp_arr, data['surface'], data['price'], c=tmp_arr, cmap="viridis")
#on affiche le graphe 3D
plt.show()


################### régression spécifique pour séparer jeu de données d'entrainement/jeu de données de test ###################

#dans les x on met surface et arrondissement et dans les y on met le price et on prend 30% des données pour le test et 70% pour le train
xtrain, xtest, ytrain, ytest = train_test_split(data[["surface", "arrondissement"]], data[["price"]], test_size=0.3)

print(xtrain)

################### On crée ensuite la baseline puis on calcule la R2( la somme quadratique des résidus), comme valeur d'évaluation de notre regression ###################


lr = LinearRegression()
lr_baseline = lr.fit(xtrain[["surface"]], ytrain)
baseline_pred = lr_baseline.predict(xtest[["surface"]])

plt.plot(xtest[["surface"]], ytest, 'bo', markersize = 5)
plt.plot(xtest[["surface"]], baseline_pred, color="skyblue", linewidth = 2)

sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
#      surface  arrondissement
# 507     20.0             4.0
# 188     30.0             2.0
# 424     21.0             3.0
# 460     22.0             3.0
# 41      80.0             1.0
# ..       ...             ...
# 362     50.0             3.0
# 368     40.0             3.0
# 790     19.0             5.0
# 401     24.0             3.0
# 682    105.0             5.0
#
# [568 rows x 2 columns]
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator
from mpl_toolkits.mplot3d import Axes3D

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
#affichage du graphique
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
#affiche sur le graphique des petite graduation sur l'axe x et y mais aussi à l'interieur du graphique  (des grandes lignes verticale)
ax1.minorticks_on()
#affiche les lignes verticale qui sépare nos schémas
ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
#ordonne l'axe mineur si il existe pour le schéma
ax1.grid(which='minor', axis='x', linewidth=1)


################### On croise le prix avec la surface pour avoir une vision plus claire ###################
#affcihage du graphe 3D
fig = plt.figure().gca(projection='3d')

# Pour faciliter la visualisation, on va changer la valeur de l'arrondissement (10) en 5
#on récupère la valeur de tous les indices
tmp_arr = data['arrondissement'][:]
#et on change celle-ci
tmp_arr[tmp_arr == 10] = 5

#set tous les points du schéma 3D fig.scatte(axe x, axe z, axe y), c défini en fonction de quoi les couleurs change pour différencier les points
fig.scatter(tmp_arr, data['surface'], data['price'], c=tmp_arr, cmap="viridis")
#on affiche le graphe 3D
plt.show()


################### régression spécifique pour séparer jeu de données d'entrainement/jeu de données de test ###################

#dans les x on met surface et arrondissement et dans les y on met le price et on prend 30% des données pour le test et 70% pour le train
xtrain, xtest, ytrain, ytest = train_test_split(data[["surface", "arrondissement"]], data[["price"]], test_size=0.3)

print(xtrain)

################### On crée ensuite la baseline puis on calcule la R2( la somme quadratique des résidus), comme valeur d'évaluation de notre regression ###################


lr = LinearRegression()
#lr_baseline = lr.fit(xtrain[["surface"]], ytrain)
#baseline_pred = lr_baseline.predict(xtest[["surface"]])

#plt.plot(xtest[["surface"]], ytest, 'bo', markersize = 5)
#plt.plot(xtest[["surface"]], baseline_pred, color="skyblue", linewidth = 2)

sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
#      surface  arrondissement
# 659   169.00             5.0
# 404    27.08             3.0
# 805    12.00             5.0
# 255    30.00             2.0
# 48     19.00             1.0
# ..       ...             ...
# 730    27.00             5.0
# 495   160.00             4.0
# 703    33.00             5.0
# 172    30.00             2.0
# 505    27.00             4.0
#
# [568 rows x 2 columns]
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator
from mpl_toolkits.mplot3d import Axes3D

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
#affichage du graphique
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
#affiche sur le graphique des petite graduation sur l'axe x et y mais aussi à l'interieur du graphique  (des grandes lignes verticale)
ax1.minorticks_on()
#affiche les lignes verticale qui sépare nos schémas
ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
#ordonne l'axe mineur si il existe pour le schéma
ax1.grid(which='minor', axis='x', linewidth=1)


################### On croise le prix avec la surface pour avoir une vision plus claire ###################
#affcihage du graphe 3D
fig = plt.figure().gca(projection='3d')

# Pour faciliter la visualisation, on va changer la valeur de l'arrondissement (10) en 5
#on récupère la valeur de tous les indices
tmp_arr = data['arrondissement'][:]
#et on change celle-ci
tmp_arr[tmp_arr == 10] = 5

#set tous les points du schéma 3D fig.scatte(axe x, axe z, axe y), c défini en fonction de quoi les couleurs change pour différencier les points
fig.scatter(tmp_arr, data['surface'], data['price'], c=tmp_arr, cmap="viridis")
#on affiche le graphe 3D
plt.show()


################### régression spécifique pour séparer jeu de données d'entrainement/jeu de données de test ###################

#dans les x on met surface et arrondissement et dans les y on met le price et on prend 30% des données pour le test et 70% pour le train
xtrain, xtest, ytrain, ytest = train_test_split(data[["surface", "arrondissement"]], data[["price"]], test_size=0.3)

print(xtrain)

################### On crée ensuite la baseline puis on calcule la R2( la somme quadratique des résidus), comme valeur d'évaluation de notre regression ###################


lr = LinearRegression()
lr_baseline = lr.fit(xtrain[["surface"]], ytrain)
#baseline_pred = lr_baseline.predict(xtest[["surface"]])

#plt.plot(xtest[["surface"]], ytest, 'bo', markersize = 5)
#plt.plot(xtest[["surface"]], baseline_pred, color="skyblue", linewidth = 2)

sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
#      surface  arrondissement
# 805    12.00             5.0
# 335    60.84             3.0
# 466    53.00             4.0
# 105   110.00             1.0
# 502    18.00             4.0
# ..       ...             ...
# 290    40.00             3.0
# 612    55.00             4.0
# 668    14.00             5.0
# 340    90.00             3.0
# 672    30.00             5.0
#
# [568 rows x 2 columns]
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator
from mpl_toolkits.mplot3d import Axes3D

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
#affichage du graphique
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
#affiche sur le graphique des petite graduation sur l'axe x et y mais aussi à l'interieur du graphique  (des grandes lignes verticale)
ax1.minorticks_on()
#affiche les lignes verticale qui sépare nos schémas
ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
#ordonne l'axe mineur si il existe pour le schéma
ax1.grid(which='minor', axis='x', linewidth=1)


################### On croise le prix avec la surface pour avoir une vision plus claire ###################
#affcihage du graphe 3D
fig = plt.figure().gca(projection='3d')

# Pour faciliter la visualisation, on va changer la valeur de l'arrondissement (10) en 5
#on récupère la valeur de tous les indices
tmp_arr = data['arrondissement'][:]
#et on change celle-ci
tmp_arr[tmp_arr == 10] = 5

#set tous les points du schéma 3D fig.scatte(axe x, axe z, axe y), c défini en fonction de quoi les couleurs change pour différencier les points
fig.scatter(tmp_arr, data['surface'], data['price'], c=tmp_arr, cmap="viridis")
#on affiche le graphe 3D
plt.show()


################### régression spécifique pour séparer jeu de données d'entrainement/jeu de données de test ###################

#dans les x on met surface et arrondissement et dans les y on met le price et on prend 30% des données pour le test et 70% pour le train
xtrain, xtest, ytrain, ytest = train_test_split(data[["surface", "arrondissement"]], data[["price"]], test_size=0.3)

print(xtrain)

################### On crée ensuite la baseline puis on calcule la R2( la somme quadratique des résidus), comme valeur d'évaluation de notre regression ###################

#calcul de la somme quadratique
lr = LinearRegression()
lr_baseline = lr.fit(xtrain[["surface"]], ytrain)
baseline_pred = lr_baseline.predict(xtest[["surface"]])

#plt.plot(xtest[["surface"]], ytest, 'bo', markersize = 5)
#plt.plot(xtest[["surface"]], baseline_pred, color="skyblue", linewidth = 2)

sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
#      surface  arrondissement
# 237    50.00             2.0
# 421    49.33             3.0
# 671    25.00             5.0
# 93     42.80             1.0
# 301    53.33             3.0
# ..       ...             ...
# 469    73.00             4.0
# 236    29.60             2.0
# 709    38.67             5.0
# 205    60.00             2.0
# 284    57.00             2.0
#
# [568 rows x 2 columns]
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator
from mpl_toolkits.mplot3d import Axes3D

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
#affichage du graphique
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
#affiche sur le graphique des petite graduation sur l'axe x et y mais aussi à l'interieur du graphique  (des grandes lignes verticale)
ax1.minorticks_on()
#affiche les lignes verticale qui sépare nos schémas
ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
#ordonne l'axe mineur si il existe pour le schéma
ax1.grid(which='minor', axis='x', linewidth=1)


################### On croise le prix avec la surface pour avoir une vision plus claire ###################
#affcihage du graphe 3D
fig = plt.figure().gca(projection='3d')

# Pour faciliter la visualisation, on va changer la valeur de l'arrondissement (10) en 5
#on récupère la valeur de tous les indices
tmp_arr = data['arrondissement'][:]
#et on change celle-ci
tmp_arr[tmp_arr == 10] = 5

#set tous les points du schéma 3D fig.scatte(axe x, axe z, axe y), c défini en fonction de quoi les couleurs change pour différencier les points
fig.scatter(tmp_arr, data['surface'], data['price'], c=tmp_arr, cmap="viridis")
#on affiche le graphe 3D
plt.show()


################### régression spécifique pour séparer jeu de données d'entrainement/jeu de données de test ###################

#dans les x on met surface et arrondissement et dans les y on met le price et on prend 30% des données pour le test et 70% pour le train
xtrain, xtest, ytrain, ytest = train_test_split(data[["surface", "arrondissement"]], data[["price"]], test_size=0.3)

print(xtrain)

################### On crée ensuite la baseline puis on calcule la R2( la somme quadratique des résidus), comme valeur d'évaluation de notre regression ###################

#calcul de la somme quadratique
lr = LinearRegression()
lr_baseline = lr.fit(xtrain[["surface"]], ytrain)
baseline_pred = lr_baseline.predict(xtest[["surface"]])
print(lr)

#plt.plot(xtest[["surface"]], ytest, 'bo', markersize = 5)
#plt.plot(xtest[["surface"]], baseline_pred, color="skyblue", linewidth = 2)

sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
#      surface  arrondissement
# 483    58.56             4.0
# 569    40.00             4.0
# 470    64.00             4.0
# 11     68.95             1.0
# 711    47.00             5.0
# ..       ...             ...
# 309    91.29             3.0
# 763    33.00             5.0
# 406    38.62             3.0
# 550    29.00             4.0
# 616    16.00             4.0
#
# [568 rows x 2 columns]
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator
from mpl_toolkits.mplot3d import Axes3D

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
#affichage du graphique
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
#affiche sur le graphique des petite graduation sur l'axe x et y mais aussi à l'interieur du graphique  (des grandes lignes verticale)
ax1.minorticks_on()
#affiche les lignes verticale qui sépare nos schémas
ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
#ordonne l'axe mineur si il existe pour le schéma
ax1.grid(which='minor', axis='x', linewidth=1)


################### On croise le prix avec la surface pour avoir une vision plus claire ###################
#affcihage du graphe 3D
fig = plt.figure().gca(projection='3d')

# Pour faciliter la visualisation, on va changer la valeur de l'arrondissement (10) en 5
#on récupère la valeur de tous les indices
tmp_arr = data['arrondissement'][:]
#et on change celle-ci
tmp_arr[tmp_arr == 10] = 5

#set tous les points du schéma 3D fig.scatte(axe x, axe z, axe y), c défini en fonction de quoi les couleurs change pour différencier les points
fig.scatter(tmp_arr, data['surface'], data['price'], c=tmp_arr, cmap="viridis")
#on affiche le graphe 3D
plt.show()


################### régression spécifique pour séparer jeu de données d'entrainement/jeu de données de test ###################

#dans les x on met surface et arrondissement et dans les y on met le price et on prend 30% des données pour le test et 70% pour le train
xtrain, xtest, ytrain, ytest = train_test_split(data[["surface", "arrondissement"]], data[["price"]], test_size=0.3)

print(xtrain)

################### On crée ensuite la baseline puis on calcule la R2( la somme quadratique des résidus), comme valeur d'évaluation de notre regression ###################

#calcul de la somme quadratique
lr = LinearRegression()
lr_baseline = lr.fit(xtrain[["surface"]], ytrain)
baseline_pred = lr_baseline.predict(xtest[["surface"]])
print(lr_baseline)

#plt.plot(xtest[["surface"]], ytest, 'bo', markersize = 5)
#plt.plot(xtest[["surface"]], baseline_pred, color="skyblue", linewidth = 2)

sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
#      surface  arrondissement
# 492    123.0             4.0
# 508     28.2             4.0
# 2       55.0             1.0
# 16      76.0             1.0
# 102     73.6             1.0
# ..       ...             ...
# 138     37.0             1.0
# 360     28.0             3.0
# 281     18.0             2.0
# 245     30.0             2.0
# 213     70.0             2.0
#
# [568 rows x 2 columns]
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator
from mpl_toolkits.mplot3d import Axes3D

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
#affichage du graphique
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
#affiche sur le graphique des petite graduation sur l'axe x et y mais aussi à l'interieur du graphique  (des grandes lignes verticale)
ax1.minorticks_on()
#affiche les lignes verticale qui sépare nos schémas
ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
#ordonne l'axe mineur si il existe pour le schéma
ax1.grid(which='minor', axis='x', linewidth=1)


################### On croise le prix avec la surface pour avoir une vision plus claire ###################
#affcihage du graphe 3D
fig = plt.figure().gca(projection='3d')

# Pour faciliter la visualisation, on va changer la valeur de l'arrondissement (10) en 5
#on récupère la valeur de tous les indices
tmp_arr = data['arrondissement'][:]
#et on change celle-ci
tmp_arr[tmp_arr == 10] = 5

#set tous les points du schéma 3D fig.scatte(axe x, axe z, axe y), c défini en fonction de quoi les couleurs change pour différencier les points
fig.scatter(tmp_arr, data['surface'], data['price'], c=tmp_arr, cmap="viridis")
#on affiche le graphe 3D
plt.show()


################### régression spécifique pour séparer jeu de données d'entrainement/jeu de données de test ###################

#dans les x on met surface et arrondissement et dans les y on met le price et on prend 30% des données pour le test et 70% pour le train
xtrain, xtest, ytrain, ytest = train_test_split(data[["surface", "arrondissement"]], data[["price"]], test_size=0.3)

print(xtrain)

################### On crée ensuite la baseline puis on calcule la R2( la somme quadratique des résidus), comme valeur d'évaluation de notre regression ###################

#calcul de la somme quadratique
lr = LinearRegression()
lr_baseline = lr.fit(xtrain[["surface"]], ytrain)
baseline_pred = lr_baseline.predict(xtest[["surface"]])
print(baseline_pred)

#plt.plot(xtest[["surface"]], ytest, 'bo', markersize = 5)
#plt.plot(xtest[["surface"]], baseline_pred, color="skyblue", linewidth = 2)

sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
#      surface  arrondissement
# 136   200.00             1.0
# 523    55.00             4.0
# 774    20.00             5.0
# 685    32.00             5.0
# 265    30.00             2.0
# ..       ...             ...
# 738    51.50             5.0
# 152    40.00             1.0
# 782    82.75             5.0
# 322    23.00             3.0
# 105   110.00             1.0
#
# [568 rows x 2 columns]
# [[3217.68996591]
#  [1994.27740274]
#  [1236.92676839]
#  [1702.98869722]
#  [1134.97572146]
#  [1305.37961419]
#  [ 952.92028051]
#  [1411.6999917 ]
#  [1414.32159005]
#  [ 799.99371012]
#  [1543.6537753 ]
#  [ 945.63806288]
#  [2285.56610825]
#  [ 858.25145122]
#  [1906.89079108]
#  [1848.63304998]
#  [1673.85982667]
#  [3538.10754198]
#  [1848.63304998]
#  [1120.41128619]
#  [ 855.04727546]
#  [1702.98869722]
#  [2285.56610825]
#  [ 974.76693343]
#  [1236.92676839]
#  [1586.47321501]
#  [3305.07657756]
#  [1070.89220625]
#  [3013.78787205]
#  [1091.28241563]
#  [1777.84989454]
#  [ 596.38290496]
#  [1557.34434446]
#  [1528.21547391]
#  [1732.11756777]
#  [1120.41128619]
#  [ 855.33856417]
#  [1207.79789784]
#  [ 974.76693343]
#  [ 938.35584524]
#  [ 799.99371012]
#  [1577.73455385]
#  [1411.6999917 ]
#  [1994.27740274]
#  [1761.24643832]
#  [2432.37561583]
#  [ 770.86483957]
#  [3567.23641253]
#  [1353.4422506 ]
#  [1207.79789784]
#  [3334.20544812]
#  [2343.82384936]
#  [2672.98008659]
#  [2110.79288494]
#  [5169.32429287]
#  [1149.54015674]
#  [1120.41128619]
#  [1965.14853219]
#  [ 829.12258067]
#  [4335.65601768]
#  [ 887.38032177]
#  [ 770.86483957]
#  [2576.85481377]
#  [ 945.63806288]
#  [1615.60208557]
#  [3159.43222481]
#  [ 725.1325128 ]
#  [1411.6999917 ]
#  [1033.02467453]
#  [1124.78061677]
#  [3130.30335425]
#  [1073.5138046 ]
#  [1702.98869722]
#  [1120.41128619]
#  [2110.79288494]
#  [1236.92676839]
#  [1033.02467453]
#  [ 945.63806288]
#  [1003.89580398]
#  [1411.6999917 ]
#  [1411.6999917 ]
#  [1035.35498418]
#  [2081.66401439]
#  [1440.82886225]
#  [3625.49415363]
#  [2169.05062605]
#  [1382.57112115]
#  [ 654.34935736]
#  [2454.80484616]
#  [ 849.51279006]
#  [2818.62443935]
#  [ 537.83387515]
#  [1062.15354508]
#  [4886.77424852]
#  [1178.66902729]
#  [1430.05118015]
#  [1761.24643832]
#  [ 758.33942523]
#  [ 770.86483957]
#  [1732.11756777]
#  [2285.56610825]
#  [ 887.38032177]
#  [1240.13094415]
#  [5344.09751618]
#  [1848.63304998]
#  [ 945.63806288]
#  [2290.51801625]
#  [1382.57112115]
#  [ 858.25145122]
#  [2724.53818747]
#  [3392.46318922]
#  [1207.79789784]
#  [3045.82962965]
#  [1411.6999917 ]
#  [1411.6999917 ]
#  [3275.94770701]
#  [ 799.99371012]
#  [1702.98869722]
#  [2323.43363997]
#  [ 683.47822791]
#  [2431.21046101]
#  [1702.98869722]
#  [1469.95773281]
#  [1040.59818087]
#  [1005.0609588 ]
#  [1236.92676839]
#  [ 890.58449753]
#  [1906.89079108]
#  [ 537.83387515]
#  [ 974.76693343]
#  [2868.14351929]
#  [1102.93396386]
#  [1266.05563894]
#  [1598.70734065]
#  [ 770.86483957]
#  [1819.50417943]
#  [1702.98869722]
#  [3246.81883646]
#  [2254.98079417]
#  [3246.81883646]
#  [ 974.76693343]
#  [1266.05563894]
#  [2314.69497881]
#  [1236.92676839]
#  [1033.02467453]
#  [3305.07657756]
#  [ 919.42207938]
#  [1236.92676839]
#  [1126.2370603 ]
#  [4615.87575239]
#  [1411.6999917 ]
#  [2795.32134291]
#  [ 683.47822791]
#  [1440.82886225]
#  [ 540.74676221]
#  [1120.41128619]
#  [1952.33182914]
#  [1502.58206782]
#  [1702.98869722]
#  [1091.28241563]
#  [1819.50417943]
#  [1528.21547391]
#  [2314.69497881]
#  [ 770.86483957]
#  [3072.04561315]
#  [1211.0020736 ]
#  [3538.39883068]
#  [1178.66902729]
#  [2364.21405874]
#  [ 974.76693343]
#  [ 846.599903  ]
#  [ 928.16074055]
#  [1120.41128619]
#  [3392.46318922]
#  [4936.29332846]
#  [1033.02467453]
#  [5300.69549906]
#  [1737.65205318]
#  [3309.44590815]
#  [1108.75973797]
#  [1062.15354508]
#  [1105.84685091]
#  [1236.92676839]
#  [3275.94770701]
#  [2722.49916653]
#  [1120.41128619]
#  [2489.46820212]
#  [4498.77769277]
#  [1506.95139841]
#  [1178.66902729]
#  [3654.62302418]
#  [2459.75675415]
#  [1292.27162244]
#  [ 699.20781801]
#  [ 887.38032177]
#  [ 829.12258067]
#  [1702.98869722]
#  [1994.27740274]
#  [1353.4422506 ]
#  [3508.97867143]
#  [1353.4422506 ]
#  [3909.20935281]
#  [2294.30476942]
#  [1906.30821367]
#  [2285.56610825]
#  [4761.52010515]
#  [1091.28241563]
#  [ 708.82034529]
#  [ 596.09161626]
#  [2110.79288494]
#  [3042.9167426 ]
#  [ 829.12258067]
#  [1877.76192053]
#  [1589.38610207]
#  [1619.38883874]
#  [ 974.76693343]
#  [1562.87882987]
#  [1557.34434446]
#  [1353.4422506 ]
#  [1207.79789784]
#  [1848.63304998]
#  [1615.60208557]
#  [ 919.42207938]
#  [1295.1845095 ]
#  [3305.07657756]
#  [1062.15354508]
#  [ 770.86483957]
#  [ 938.35584524]
#  [1600.16378417]
#  [3392.46318922]
#  [ 887.38032177]
#  [1848.63304998]
#  [3508.97867143]
#  [ 727.17153374]
#  [ 945.63806288]
#  [1266.05563894]
#  [1702.98869722]
#  [3246.81883646]
#  [ 974.76693343]
#  [2285.56610825]
#  [3042.9167426 ]
#  [2285.56610825]
#  [1062.15354508]
#  [2285.56610825]]
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# On importe les librairies dont on aura besoin pour ce tp
#%matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import seaborn as sns
from matplotlib.ticker import AutoMinorLocator
from mpl_toolkits.mplot3d import Axes3D

################### Première phase: exploration/nettoyage des données ###################
#chargement des données
raw_data = pd.read_csv('house_data_more_precise.csv')

#résumé des données brutes, avec ça on voit que i a pas le même nombre de ligne donc on va trier
#print(raw_data.describe())

#quelques valeurs manquante donc on supprime des lignes
data_na = raw_data.dropna()

#on enlève les outliers qui sont dans notre dataset sur les grandes propriétés
data = data_na[data_na["price"] < 8000]

#on réindexe
data = data.reset_index(drop = True)

print(data)

#on affiche les données nettoyés
print(data.plot.scatter('price','surface', c='arrondissement', colormap='viridis'))

################### Affichage de la varable prédite(price) en fonction de l'arrondissement ###################
#affichage du graphique
ax1 = sns.violinplot(x='arrondissement', y='price', data=data, hue= 'arrondissement')
#affiche sur le graphique des petite graduation sur l'axe x et y mais aussi à l'interieur du graphique  (des grandes lignes verticale)
ax1.minorticks_on()
#affiche les lignes verticale qui sépare nos schémas
ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
#ordonne l'axe mineur si il existe pour le schéma
ax1.grid(which='minor', axis='x', linewidth=1)


################### On croise le prix avec la surface pour avoir une vision plus claire ###################
#affcihage du graphe 3D
fig = plt.figure().gca(projection='3d')

# Pour faciliter la visualisation, on va changer la valeur de l'arrondissement (10) en 5
#on récupère la valeur de tous les indices
tmp_arr = data['arrondissement'][:]
#et on change celle-ci
tmp_arr[tmp_arr == 10] = 5

#set tous les points du schéma 3D fig.scatte(axe x, axe z, axe y), c défini en fonction de quoi les couleurs change pour différencier les points
fig.scatter(tmp_arr, data['surface'], data['price'], c=tmp_arr, cmap="viridis")
#on affiche le graphe 3D
plt.show()


################### régression spécifique pour séparer jeu de données d'entrainement/jeu de données de test ###################

#dans les x on met surface et arrondissement et dans les y on met le price et on prend 30% des données pour le test et 70% pour le train
xtrain, xtest, ytrain, ytest = train_test_split(data[["surface", "arrondissement"]], data[["price"]], test_size=0.3)

print(xtrain)

################### On crée ensuite la baseline puis on calcule la R2( la somme quadratique des résidus), comme valeur d'évaluation de notre regression ###################

#calcul de la somme quadratique
lr = LinearRegression()
lr_baseline = lr.fit(xtrain[["surface"]], ytrain)
baseline_pred = lr_baseline.predict(xtest[["surface"]])

#on affiche le graphique
plt.plot(xtest[["surface"]], ytest, 'bo', markersize = 5)
plt.plot(xtest[["surface"]], baseline_pred, color="skyblue", linewidth = 2)

sys.exit(0)

#on donne à data les valeurs des arrondissement
data_from_csv = pd.DataFrame(house_data)
data = pd.DataFrame({'arrondissement': [1, 2, 3, 4,10]})

#ça prend les 3 premières colonnes et ça les classe
train, test = train_test_split(house_data, train_size=0.8)

mean_price = data_from_csv.groupby('arrondissement').mean()

#résultat de la moyenne de la surface et de la moyenne du loyer
print(mean_price)
#affichage pour réunir par arrondissement
print(data.merge(mean_price, on='arrondissement'))
sys.exit(0)
print(data)
print(train)
print(test)




X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['price']).T
# On effectue le calcul exact du paramètre theta
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

#print(theta.item(0) + theta.item(1) * 20)

plt.xlabel('surface')
plt.ylabel('price')

#on affiche les points avec une taille égale à markersize et une couleur rouge indiqué par le ro
plt.plot(house_data['surface'], house_data['price'], 'o', markersize=3)

plt.show()

print(pd.get_dummies(data))
# Out:
#      price  surface  arrondissement
# 0     1820    46.10             1.0
# 1     1750    41.00             1.0
# 2     1900    55.00             1.0
# 3     1950    46.00             1.0
# 4     1950    49.00             1.0
# ..     ...      ...             ...
# 807    850    35.00            10.0
# 808    700    10.00            10.0
# 809   1280    34.00            10.0
# 810   1545    65.00            10.0
# 811   1000    21.43            10.0
#
# [812 rows x 3 columns]
# AxesSubplot(0.125,0.125;0.62x0.755)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:304: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
#      surface  arrondissement
# 72     16.90             1.0
# 168    62.00             2.0
# 546    50.00             4.0
# 134   109.55             1.0
# 493   124.31             4.0
# ..       ...             ...
# 366    36.35             3.0
# 465    53.00             4.0
# 124    33.11             1.0
# 692    50.00             5.0
# 775    20.00             5.0
#
# [568 rows x 2 columns]
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
